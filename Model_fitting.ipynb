# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Defining-and-implementing-a-cost-function" data-toc-modified-id="Defining-and-implementing-a-cost-function-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Defining and implementing a cost function</a></span></li><li><span><a href="#Solving-for-optimal-estimate" data-toc-modified-id="Solving-for-optimal-estimate-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Solving for optimal estimate</a></span></li><li><span><a href="#Look-up-table" data-toc-modified-id="Look-up-table-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Look up table</a></span><ul class="toc-item"><li><span><a href="#A-faster-LUT" data-toc-modified-id="A-faster-LUT-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>A faster LUT</a></span></li></ul></li><li><span><a href="#Exercise" data-toc-modified-id="Exercise-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Exercise</a></span></li><li><span><a href="#Using-a-minimisation-routine" data-toc-modified-id="Using-a-minimisation-routine-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Using a minimisation routine</a></span></li><li><span><a href="#Exercise" data-toc-modified-id="Exercise-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Exercise</a></span></li></ul></div>

# %%
from geog0111.geog_data import procure_dataset

_ = procure_dataset("lai_data")
# Out:
# Remote file: MCD15A3H.A2016001.h17v03.006.2016007075833.hdf (2280044 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016001.h17v03.006.2016007075833.hdf (2280044 bytes) -> ✓
# Remote file: MCD15A3H.A2016001.h17v04.006.2016007074809.hdf (4260586 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016001.h17v04.006.2016007074809.hdf (4260586 bytes) -> ✓
# Remote file: MCD15A3H.A2016001.h18v03.006.2016007073724.hdf (5286979 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016001.h18v03.006.2016007073724.hdf (5286979 bytes) -> ✓
# Remote file: MCD15A3H.A2016001.h18v04.006.2016007073726.hdf (8444045 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016001.h18v04.006.2016007073726.hdf (8444045 bytes) -> ✓
# Remote file: MCD15A3H.A2016005.h17v03.006.2016013012017.hdf (2746245 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016005.h17v03.006.2016013012017.hdf (2746245 bytes) -> ✓
# Remote file: MCD15A3H.A2016005.h17v04.006.2016013011406.hdf (4109634 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016005.h17v04.006.2016013011406.hdf (4109634 bytes) -> ✓
# Remote file: MCD15A3H.A2016005.h18v03.006.2016013012348.hdf (5892502 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016005.h18v03.006.2016013012348.hdf (5892502 bytes) -> ✓
# Remote file: MCD15A3H.A2016005.h18v04.006.2016013012025.hdf (8891033 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016005.h18v04.006.2016013012025.hdf (8891033 bytes) -> ✓
# Remote file: MCD15A3H.A2016009.h17v03.006.2016014071957.hdf (2786519 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016009.h17v03.006.2016014071957.hdf (2786519 bytes) -> ✓
# Remote file: MCD15A3H.A2016009.h17v04.006.2016014072006.hdf (4681121 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016009.h17v04.006.2016014072006.hdf (4681121 bytes) -> ✓
# Remote file: MCD15A3H.A2016009.h18v03.006.2016014073048.hdf (4798396 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016009.h18v03.006.2016014073048.hdf (4798396 bytes) -> ✓
# Remote file: MCD15A3H.A2016009.h18v04.006.2016014074158.hdf (8502139 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016009.h18v04.006.2016014074158.hdf (8502139 bytes) -> ✓
# Remote file: MCD15A3H.A2016013.h17v03.006.2016020015242.hdf (2969123 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016013.h17v03.006.2016020015242.hdf (2969123 bytes) -> ✓
# Remote file: MCD15A3H.A2016013.h17v04.006.2016020020246.hdf (4781324 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016013.h17v04.006.2016020020246.hdf (4781324 bytes) -> ✓
# Remote file: MCD15A3H.A2016013.h18v03.006.2016020014424.hdf (5536317 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016013.h18v03.006.2016020014424.hdf (5536317 bytes) -> ✓
# Remote file: MCD15A3H.A2016013.h18v04.006.2016020014435.hdf (9862598 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016013.h18v04.006.2016020014435.hdf (9862598 bytes) -> ✓
# Remote file: MCD15A3H.A2016017.h17v03.006.2016027192752.hdf (2647136 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016017.h17v03.006.2016027192752.hdf (2647136 bytes) -> ✓
# Remote file: MCD15A3H.A2016017.h17v04.006.2016027192758.hdf (4199720 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016017.h17v04.006.2016027192758.hdf (4199720 bytes) -> ✓
# Remote file: MCD15A3H.A2016017.h18v03.006.2016027193558.hdf (5879988 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016017.h18v03.006.2016027193558.hdf (5879988 bytes) -> ✓
# Remote file: MCD15A3H.A2016017.h18v04.006.2016027193356.hdf (8820928 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016017.h18v04.006.2016027193356.hdf (8820928 bytes) -> ✓
# Remote file: MCD15A3H.A2016021.h17v03.006.2016026124738.hdf (2639017 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016021.h17v03.006.2016026124738.hdf (2639017 bytes) -> ✓
# Remote file: MCD15A3H.A2016021.h17v04.006.2016026124414.hdf (4642889 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016021.h17v04.006.2016026124414.hdf (4642889 bytes) -> ✓
# Remote file: MCD15A3H.A2016021.h18v03.006.2016026124743.hdf (5689895 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016021.h18v03.006.2016026124743.hdf (5689895 bytes) -> ✓
# Remote file: MCD15A3H.A2016021.h18v04.006.2016026124707.hdf (10006485 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016021.h18v04.006.2016026124707.hdf (10006485 bytes) -> ✓
# Remote file: MCD15A3H.A2016025.h17v03.006.2016034034334.hdf (2820912 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016025.h17v03.006.2016034034334.hdf (2820912 bytes) -> ✓
# Remote file: MCD15A3H.A2016025.h17v04.006.2016034035837.hdf (4693527 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016025.h17v04.006.2016034035837.hdf (4693527 bytes) -> ✓
# Remote file: MCD15A3H.A2016025.h18v03.006.2016034034341.hdf (6315096 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016025.h18v03.006.2016034034341.hdf (6315096 bytes) -> ✓
# Remote file: MCD15A3H.A2016025.h18v04.006.2016034034846.hdf (10347362 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016025.h18v04.006.2016034034846.hdf (10347362 bytes) -> ✓
# Remote file: MCD15A3H.A2016029.h17v03.006.2016043140323.hdf (3191203 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016029.h17v03.006.2016043140323.hdf (3191203 bytes) -> ✓
# Remote file: MCD15A3H.A2016029.h17v04.006.2016043140330.hdf (3967475 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016029.h17v04.006.2016043140330.hdf (3967475 bytes) -> ✓
# Remote file: MCD15A3H.A2016029.h18v03.006.2016043140341.hdf (5485940 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016029.h18v03.006.2016043140341.hdf (5485940 bytes) -> ✓
# Remote file: MCD15A3H.A2016029.h18v04.006.2016043140353.hdf (10017561 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016029.h18v04.006.2016043140353.hdf (10017561 bytes) -> ✓
# Remote file: MCD15A3H.A2016033.h17v03.006.2016043140622.hdf (3272665 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016033.h17v03.006.2016043140622.hdf (3272665 bytes) -> ✓
# Remote file: MCD15A3H.A2016033.h17v04.006.2016043140634.hdf (4831562 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016033.h17v04.006.2016043140634.hdf (4831562 bytes) -> ✓
# Remote file: MCD15A3H.A2016033.h18v03.006.2016043140641.hdf (6683217 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016033.h18v03.006.2016043140641.hdf (6683217 bytes) -> ✓
# Remote file: MCD15A3H.A2016033.h18v04.006.2016043140709.hdf (10403638 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016033.h18v04.006.2016043140709.hdf (10403638 bytes) -> ✓
# Remote file: MCD15A3H.A2016037.h17v03.006.2016043140850.hdf (3041123 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016037.h17v03.006.2016043140850.hdf (3041123 bytes) -> ✓
# Remote file: MCD15A3H.A2016037.h17v04.006.2016043140849.hdf (4379742 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016037.h17v04.006.2016043140849.hdf (4379742 bytes) -> ✓
# Remote file: MCD15A3H.A2016037.h18v03.006.2016043140917.hdf (6615605 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016037.h18v03.006.2016043140917.hdf (6615605 bytes) -> ✓
# Remote file: MCD15A3H.A2016037.h18v04.006.2016043140911.hdf (9600309 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016037.h18v04.006.2016043140911.hdf (9600309 bytes) -> ✓
# Remote file: MCD15A3H.A2016041.h17v03.006.2016049125032.hdf (3952098 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016041.h17v03.006.2016049125032.hdf (3952098 bytes) -> ✓
# Remote file: MCD15A3H.A2016041.h17v04.006.2016049125048.hdf (4589994 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016041.h17v04.006.2016049125048.hdf (4589994 bytes) -> ✓
# Remote file: MCD15A3H.A2016041.h18v03.006.2016049125050.hdf (7261069 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016041.h18v03.006.2016049125050.hdf (7261069 bytes) -> ✓
# Remote file: MCD15A3H.A2016041.h18v04.006.2016049125059.hdf (10726858 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016041.h18v04.006.2016049125059.hdf (10726858 bytes) -> ✓
# Remote file: MCD15A3H.A2016045.h17v03.006.2016054001450.hdf (3902250 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016045.h17v03.006.2016054001450.hdf (3902250 bytes) -> ✓
# Remote file: MCD15A3H.A2016045.h17v04.006.2016054001456.hdf (4882686 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016045.h17v04.006.2016054001456.hdf (4882686 bytes) -> ✓
# Remote file: MCD15A3H.A2016045.h18v03.006.2016054001450.hdf (7675481 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016045.h18v03.006.2016054001450.hdf (7675481 bytes) -> ✓
# Remote file: MCD15A3H.A2016045.h18v04.006.2016054001527.hdf (8937344 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016045.h18v04.006.2016054001527.hdf (8937344 bytes) -> ✓
# Remote file: MCD15A3H.A2016049.h17v03.006.2016111145759.hdf (3861770 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016049.h17v03.006.2016111145759.hdf (3861770 bytes) -> ✓
# Remote file: MCD15A3H.A2016049.h17v04.006.2016111145800.hdf (4609484 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016049.h17v04.006.2016111145800.hdf (4609484 bytes) -> ✓
# Remote file: MCD15A3H.A2016049.h18v03.006.2016111145825.hdf (6149195 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016049.h18v03.006.2016111145825.hdf (6149195 bytes) -> ✓
# Remote file: MCD15A3H.A2016049.h18v04.006.2016111145832.hdf (9919046 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016049.h18v04.006.2016111145832.hdf (9919046 bytes) -> ✓
# Remote file: MCD15A3H.A2016057.h17v03.006.2016111145933.hdf (3494768 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016057.h17v03.006.2016111145933.hdf (3494768 bytes) -> ✓
# Remote file: MCD15A3H.A2016057.h17v04.006.2016111145935.hdf (4655953 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016057.h17v04.006.2016111145935.hdf (4655953 bytes) -> ✓
# Remote file: MCD15A3H.A2016057.h18v03.006.2016111145941.hdf (7953165 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016057.h18v03.006.2016111145941.hdf (7953165 bytes) -> ✓
# Remote file: MCD15A3H.A2016057.h18v04.006.2016111145944.hdf (8750236 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016057.h18v04.006.2016111145944.hdf (8750236 bytes) -> ✓
# Remote file: MCD15A3H.A2016061.h17v03.006.2016110203331.hdf (3890177 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016061.h17v03.006.2016110203331.hdf (3890177 bytes) -> ✓
# Remote file: MCD15A3H.A2016061.h17v04.006.2016110203339.hdf (4763355 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016061.h17v04.006.2016110203339.hdf (4763355 bytes) -> ✓
# Remote file: MCD15A3H.A2016061.h18v03.006.2016110203332.hdf (6966044 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016061.h18v03.006.2016110203332.hdf (6966044 bytes) -> ✓
# Remote file: MCD15A3H.A2016061.h18v04.006.2016110203352.hdf (9981871 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016061.h18v04.006.2016110203352.hdf (9981871 bytes) -> ✓
# Remote file: MCD15A3H.A2016065.h17v03.006.2016110203443.hdf (4198833 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016065.h17v03.006.2016110203443.hdf (4198833 bytes) -> ✓
# Remote file: MCD15A3H.A2016065.h17v04.006.2016110203445.hdf (4928021 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016065.h17v04.006.2016110203445.hdf (4928021 bytes) -> ✓
# Remote file: MCD15A3H.A2016065.h18v03.006.2016110203500.hdf (6862908 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016065.h18v03.006.2016110203500.hdf (6862908 bytes) -> ✓
# Remote file: MCD15A3H.A2016065.h18v04.006.2016110203503.hdf (9975395 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016065.h18v04.006.2016110203503.hdf (9975395 bytes) -> ✓
# Remote file: MCD15A3H.A2016069.h17v03.006.2016110203559.hdf (3989144 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016069.h17v03.006.2016110203559.hdf (3989144 bytes) -> ✓
# Remote file: MCD15A3H.A2016069.h17v04.006.2016110203600.hdf (4822638 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016069.h17v04.006.2016110203600.hdf (4822638 bytes) -> ✓
# Remote file: MCD15A3H.A2016069.h18v03.006.2016110203608.hdf (7612177 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016069.h18v03.006.2016110203608.hdf (7612177 bytes) -> ✓
# Remote file: MCD15A3H.A2016069.h18v04.006.2016110203615.hdf (10716160 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016069.h18v04.006.2016110203615.hdf (10716160 bytes) -> ✓
# Remote file: MCD15A3H.A2016073.h17v03.006.2016110203711.hdf (3919861 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016073.h17v03.006.2016110203711.hdf (3919861 bytes) -> ✓
# Remote file: MCD15A3H.A2016073.h17v04.006.2016110203728.hdf (4766546 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016073.h17v04.006.2016110203728.hdf (4766546 bytes) -> ✓
# Remote file: MCD15A3H.A2016073.h18v03.006.2016110203721.hdf (7924866 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016073.h18v03.006.2016110203721.hdf (7924866 bytes) -> ✓
# Remote file: MCD15A3H.A2016073.h18v04.006.2016110203727.hdf (10773317 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016073.h18v04.006.2016110203727.hdf (10773317 bytes) -> ✓
# Remote file: MCD15A3H.A2016077.h17v03.006.2016110203826.hdf (3848660 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016077.h17v03.006.2016110203826.hdf (3848660 bytes) -> ✓
# Remote file: MCD15A3H.A2016077.h17v04.006.2016110203826.hdf (4681023 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016077.h17v04.006.2016110203826.hdf (4681023 bytes) -> ✓
# Remote file: MCD15A3H.A2016077.h18v03.006.2016110203839.hdf (7851520 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016077.h18v03.006.2016110203839.hdf (7851520 bytes) -> ✓
# Remote file: MCD15A3H.A2016077.h18v04.006.2016110203846.hdf (10901169 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016077.h18v04.006.2016110203846.hdf (10901169 bytes) -> ✓
# Remote file: MCD15A3H.A2016081.h17v03.006.2016110203940.hdf (3106412 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016081.h17v03.006.2016110203940.hdf (3106412 bytes) -> ✓
# Remote file: MCD15A3H.A2016081.h17v04.006.2016110203941.hdf (4936297 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016081.h17v04.006.2016110203941.hdf (4936297 bytes) -> ✓
# Remote file: MCD15A3H.A2016081.h18v03.006.2016110204002.hdf (7483982 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016081.h18v03.006.2016110204002.hdf (7483982 bytes) -> ✓
# Remote file: MCD15A3H.A2016081.h18v04.006.2016110203956.hdf (11254570 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016081.h18v04.006.2016110203956.hdf (11254570 bytes) -> ✓
# Remote file: MCD15A3H.A2016085.h17v03.006.2016110204055.hdf (4221498 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016085.h17v03.006.2016110204055.hdf (4221498 bytes) -> ✓
# Remote file: MCD15A3H.A2016085.h17v04.006.2016110204056.hdf (5047916 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016085.h17v04.006.2016110204056.hdf (5047916 bytes) -> ✓
# Remote file: MCD15A3H.A2016085.h18v03.006.2016110204107.hdf (8063897 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016085.h18v03.006.2016110204107.hdf (8063897 bytes) -> ✓
# Remote file: MCD15A3H.A2016085.h18v04.006.2016110204111.hdf (11092762 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016085.h18v04.006.2016110204111.hdf (11092762 bytes) -> ✓
# Remote file: MCD15A3H.A2016089.h17v03.006.2016110204215.hdf (4307198 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016089.h17v03.006.2016110204215.hdf (4307198 bytes) -> ✓
# Remote file: MCD15A3H.A2016089.h17v04.006.2016110204226.hdf (5161752 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016089.h17v04.006.2016110204226.hdf (5161752 bytes) -> ✓
# Remote file: MCD15A3H.A2016089.h18v03.006.2016110204226.hdf (8016227 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016089.h18v03.006.2016110204226.hdf (8016227 bytes) -> ✓
# Remote file: MCD15A3H.A2016089.h18v04.006.2016110204226.hdf (10575132 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016089.h18v04.006.2016110204226.hdf (10575132 bytes) -> ✓
# Remote file: MCD15A3H.A2016093.h17v03.006.2016110204329.hdf (4024737 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016093.h17v03.006.2016110204329.hdf (4024737 bytes) -> ✓
# Remote file: MCD15A3H.A2016093.h17v04.006.2016110204342.hdf (4920756 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016093.h17v04.006.2016110204342.hdf (4920756 bytes) -> ✓
# Remote file: MCD15A3H.A2016093.h18v03.006.2016110204342.hdf (7414302 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016093.h18v03.006.2016110204342.hdf (7414302 bytes) -> ✓
# Remote file: MCD15A3H.A2016093.h18v04.006.2016110204342.hdf (10214215 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016093.h18v04.006.2016110204342.hdf (10214215 bytes) -> ✓
# Remote file: MCD15A3H.A2016097.h17v03.006.2016110204444.hdf (4244290 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016097.h17v03.006.2016110204444.hdf (4244290 bytes) -> ✓
# Remote file: MCD15A3H.A2016097.h17v04.006.2016110204450.hdf (4987842 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016097.h17v04.006.2016110204450.hdf (4987842 bytes) -> ✓
# Remote file: MCD15A3H.A2016097.h18v03.006.2016110204452.hdf (8921885 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016097.h18v03.006.2016110204452.hdf (8921885 bytes) -> ✓
# Remote file: MCD15A3H.A2016097.h18v04.006.2016110204502.hdf (10895510 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016097.h18v04.006.2016110204502.hdf (10895510 bytes) -> ✓
# Remote file: MCD15A3H.A2016101.h17v03.006.2016110204557.hdf (3968059 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016101.h17v03.006.2016110204557.hdf (3968059 bytes) -> ✓
# Remote file: MCD15A3H.A2016101.h17v04.006.2016110204557.hdf (5321069 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016101.h17v04.006.2016110204557.hdf (5321069 bytes) -> ✓
# Remote file: MCD15A3H.A2016101.h18v03.006.2016110204603.hdf (8580347 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016101.h18v03.006.2016110204603.hdf (8580347 bytes) -> ✓
# Remote file: MCD15A3H.A2016101.h18v04.006.2016110204612.hdf (11975180 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016101.h18v04.006.2016110204612.hdf (11975180 bytes) -> ✓
# Remote file: MCD15A3H.A2016105.h17v03.006.2016112000529.hdf (4343757 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016105.h17v03.006.2016112000529.hdf (4343757 bytes) -> ✓
# Remote file: MCD15A3H.A2016105.h17v04.006.2016112000523.hdf (5052388 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016105.h17v04.006.2016112000523.hdf (5052388 bytes) -> ✓
# Remote file: MCD15A3H.A2016105.h18v03.006.2016112000619.hdf (8248473 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016105.h18v03.006.2016112000619.hdf (8248473 bytes) -> ✓
# Remote file: MCD15A3H.A2016105.h18v04.006.2016111235856.hdf (11629073 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016105.h18v04.006.2016111235856.hdf (11629073 bytes) -> ✓
# Remote file: MCD15A3H.A2016109.h17v03.006.2016116205141.hdf (4094553 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016109.h17v03.006.2016116205141.hdf (4094553 bytes) -> ✓
# Remote file: MCD15A3H.A2016109.h17v04.006.2016116204817.hdf (5038235 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016109.h17v04.006.2016116204817.hdf (5038235 bytes) -> ✓
# Remote file: MCD15A3H.A2016109.h18v03.006.2016116205828.hdf (8823369 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016109.h18v03.006.2016116205828.hdf (8823369 bytes) -> ✓
# Remote file: MCD15A3H.A2016109.h18v04.006.2016116205500.hdf (12082882 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016109.h18v04.006.2016116205500.hdf (12082882 bytes) -> ✓
# Remote file: MCD15A3H.A2016113.h17v03.006.2016118071447.hdf (4394511 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016113.h17v03.006.2016118071447.hdf (4394511 bytes) -> ✓
# Remote file: MCD15A3H.A2016113.h17v04.006.2016118071149.hdf (5006885 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016113.h17v04.006.2016118071149.hdf (5006885 bytes) -> ✓
# Remote file: MCD15A3H.A2016113.h18v03.006.2016118072403.hdf (9216431 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016113.h18v03.006.2016118072403.hdf (9216431 bytes) -> ✓
# Remote file: MCD15A3H.A2016113.h18v04.006.2016118071207.hdf (11346362 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016113.h18v04.006.2016118071207.hdf (11346362 bytes) -> ✓
# Remote file: MCD15A3H.A2016117.h17v03.006.2016123133231.hdf (4463901 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016117.h17v03.006.2016123133231.hdf (4463901 bytes) -> ✓
# Remote file: MCD15A3H.A2016117.h17v04.006.2016123133231.hdf (5230411 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016117.h17v04.006.2016123133231.hdf (5230411 bytes) -> ✓
# Remote file: MCD15A3H.A2016117.h18v03.006.2016123133248.hdf (9150567 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016117.h18v03.006.2016123133248.hdf (9150567 bytes) -> ✓
# Remote file: MCD15A3H.A2016117.h18v04.006.2016123133254.hdf (12748991 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016117.h18v04.006.2016123133254.hdf (12748991 bytes) -> ✓
# Remote file: MCD15A3H.A2016121.h17v03.006.2016126073150.hdf (4479319 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016121.h17v03.006.2016126073150.hdf (4479319 bytes) -> ✓
# Remote file: MCD15A3H.A2016121.h17v04.006.2016126072647.hdf (5034185 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016121.h17v04.006.2016126072647.hdf (5034185 bytes) -> ✓
# Remote file: MCD15A3H.A2016121.h18v03.006.2016126073203.hdf (9006715 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016121.h18v03.006.2016126073203.hdf (9006715 bytes) -> ✓
# Remote file: MCD15A3H.A2016121.h18v04.006.2016126072929.hdf (12290741 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016121.h18v04.006.2016126072929.hdf (12290741 bytes) -> ✓
# Remote file: MCD15A3H.A2016125.h17v03.006.2016130152307.hdf (4284784 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016125.h17v03.006.2016130152307.hdf (4284784 bytes) -> ✓
# Remote file: MCD15A3H.A2016125.h17v04.006.2016130152307.hdf (4792104 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016125.h17v04.006.2016130152307.hdf (4792104 bytes) -> ✓
# Remote file: MCD15A3H.A2016125.h18v03.006.2016130152323.hdf (9045511 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016125.h18v03.006.2016130152323.hdf (9045511 bytes) -> ✓
# Remote file: MCD15A3H.A2016125.h18v04.006.2016130152322.hdf (12463927 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016125.h18v04.006.2016130152322.hdf (12463927 bytes) -> ✓
# Remote file: MCD15A3H.A2016129.h17v03.006.2016135030155.hdf (4101071 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016129.h17v03.006.2016135030155.hdf (4101071 bytes) -> ✓
# Remote file: MCD15A3H.A2016129.h17v04.006.2016135025251.hdf (4692527 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016129.h17v04.006.2016135025251.hdf (4692527 bytes) -> ✓
# Remote file: MCD15A3H.A2016129.h18v03.006.2016135025557.hdf (9346026 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016129.h18v03.006.2016135025557.hdf (9346026 bytes) -> ✓
# Remote file: MCD15A3H.A2016129.h18v04.006.2016135032944.hdf (10615142 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016129.h18v04.006.2016135032944.hdf (10615142 bytes) -> ✓
# Remote file: MCD15A3H.A2016133.h17v03.006.2016140155029.hdf (4537006 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016133.h17v03.006.2016140155029.hdf (4537006 bytes) -> ✓
# Remote file: MCD15A3H.A2016133.h17v04.006.2016140155030.hdf (5260921 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016133.h17v04.006.2016140155030.hdf (5260921 bytes) -> ✓
# Remote file: MCD15A3H.A2016133.h18v03.006.2016140155050.hdf (9557862 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016133.h18v03.006.2016140155050.hdf (9557862 bytes) -> ✓
# Remote file: MCD15A3H.A2016133.h18v04.006.2016140155048.hdf (11506415 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016133.h18v04.006.2016140155048.hdf (11506415 bytes) -> ✓
# Remote file: MCD15A3H.A2016137.h17v03.006.2016142085015.hdf (4066602 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016137.h17v03.006.2016142085015.hdf (4066602 bytes) -> ✓
# Remote file: MCD15A3H.A2016137.h17v04.006.2016142085022.hdf (5075336 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016137.h17v04.006.2016142085022.hdf (5075336 bytes) -> ✓
# Remote file: MCD15A3H.A2016137.h18v03.006.2016142085230.hdf (8792126 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016137.h18v03.006.2016142085230.hdf (8792126 bytes) -> ✓
# Remote file: MCD15A3H.A2016137.h18v04.006.2016142090113.hdf (11971445 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016137.h18v04.006.2016142090113.hdf (11971445 bytes) -> ✓
# Remote file: MCD15A3H.A2016141.h17v03.006.2016159123250.hdf (4531091 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016141.h17v03.006.2016159123250.hdf (4531091 bytes) -> ✓
# Remote file: MCD15A3H.A2016141.h17v04.006.2016159123205.hdf (5203520 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016141.h17v04.006.2016159123205.hdf (5203520 bytes) -> ✓
# Remote file: MCD15A3H.A2016141.h18v03.006.2016159123228.hdf (8191402 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016141.h18v03.006.2016159123228.hdf (8191402 bytes) -> ✓
# Remote file: MCD15A3H.A2016141.h18v04.006.2016159123303.hdf (12289682 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016141.h18v04.006.2016159123303.hdf (12289682 bytes) -> ✓
# Remote file: MCD15A3H.A2016145.h17v03.006.2016159123331.hdf (4358454 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016145.h17v03.006.2016159123331.hdf (4358454 bytes) -> ✓
# Remote file: MCD15A3H.A2016145.h17v04.006.2016159123337.hdf (5350076 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016145.h17v04.006.2016159123337.hdf (5350076 bytes) -> ✓
# Remote file: MCD15A3H.A2016145.h18v03.006.2016159123336.hdf (9051003 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016145.h18v03.006.2016159123336.hdf (9051003 bytes) -> ✓
# Remote file: MCD15A3H.A2016145.h18v04.006.2016159123342.hdf (12748861 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016145.h18v04.006.2016159123342.hdf (12748861 bytes) -> ✓
# Remote file: MCD15A3H.A2016149.h17v03.006.2016159123409.hdf (4598492 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016149.h17v03.006.2016159123409.hdf (4598492 bytes) -> ✓
# Remote file: MCD15A3H.A2016149.h17v04.006.2016159123404.hdf (5370605 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016149.h17v04.006.2016159123404.hdf (5370605 bytes) -> ✓
# Remote file: MCD15A3H.A2016149.h18v03.006.2016159123409.hdf (9653867 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016149.h18v03.006.2016159123409.hdf (9653867 bytes) -> ✓
# Remote file: MCD15A3H.A2016149.h18v04.006.2016159123411.hdf (11606876 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016149.h18v04.006.2016159123411.hdf (11606876 bytes) -> ✓
# Remote file: MCD15A3H.A2016153.h17v03.006.2016159123426.hdf (4253027 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016153.h17v03.006.2016159123426.hdf (4253027 bytes) -> ✓
# Remote file: MCD15A3H.A2016153.h17v04.006.2016159123436.hdf (4523038 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016153.h17v04.006.2016159123436.hdf (4523038 bytes) -> ✓
# Remote file: MCD15A3H.A2016153.h18v03.006.2016159123441.hdf (9157130 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016153.h18v03.006.2016159123441.hdf (9157130 bytes) -> ✓
# Remote file: MCD15A3H.A2016153.h18v04.006.2016159123443.hdf (9629033 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016153.h18v04.006.2016159123443.hdf (9629033 bytes) -> ✓
# Remote file: MCD15A3H.A2016157.h17v03.006.2016166093852.hdf (4397338 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016157.h17v03.006.2016166093852.hdf (4397338 bytes) -> ✓
# Remote file: MCD15A3H.A2016157.h17v04.006.2016166093859.hdf (5240016 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016157.h17v04.006.2016166093859.hdf (5240016 bytes) -> ✓
# Remote file: MCD15A3H.A2016157.h18v03.006.2016166094604.hdf (9804176 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016157.h18v03.006.2016166094604.hdf (9804176 bytes) -> ✓
# Remote file: MCD15A3H.A2016157.h18v04.006.2016166093925.hdf (13250350 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016157.h18v04.006.2016166093925.hdf (13250350 bytes) -> ✓
# Remote file: MCD15A3H.A2016161.h17v03.006.2016167030656.hdf (3774621 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016161.h17v03.006.2016167030656.hdf (3774621 bytes) -> ✓
# Remote file: MCD15A3H.A2016161.h17v04.006.2016167025525.hdf (4836540 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016161.h17v04.006.2016167025525.hdf (4836540 bytes) -> ✓
# Remote file: MCD15A3H.A2016161.h18v03.006.2016167030705.hdf (9785298 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016161.h18v03.006.2016167030705.hdf (9785298 bytes) -> ✓
# Remote file: MCD15A3H.A2016161.h18v04.006.2016167030708.hdf (12114572 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016161.h18v04.006.2016167030708.hdf (12114572 bytes) -> ✓
# Remote file: MCD15A3H.A2016165.h17v03.006.2016173050525.hdf (3415185 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016165.h17v03.006.2016173050525.hdf (3415185 bytes) -> ✓
# Remote file: MCD15A3H.A2016165.h17v04.006.2016173045301.hdf (5204374 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016165.h17v04.006.2016173045301.hdf (5204374 bytes) -> ✓
# Remote file: MCD15A3H.A2016165.h18v03.006.2016173045725.hdf (9187935 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016165.h18v03.006.2016173045725.hdf (9187935 bytes) -> ✓
# Remote file: MCD15A3H.A2016165.h18v04.006.2016173045552.hdf (11807347 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016165.h18v04.006.2016173045552.hdf (11807347 bytes) -> ✓
# Remote file: MCD15A3H.A2016169.h17v03.006.2016180114611.hdf (3897511 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016169.h17v03.006.2016180114611.hdf (3897511 bytes) -> ✓
# Remote file: MCD15A3H.A2016169.h17v04.006.2016180114633.hdf (5018872 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016169.h17v04.006.2016180114633.hdf (5018872 bytes) -> ✓
# Remote file: MCD15A3H.A2016169.h18v03.006.2016180114625.hdf (9469696 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016169.h18v03.006.2016180114625.hdf (9469696 bytes) -> ✓
# Remote file: MCD15A3H.A2016169.h18v04.006.2016180114625.hdf (12757310 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016169.h18v04.006.2016180114625.hdf (12757310 bytes) -> ✓
# Remote file: MCD15A3H.A2016173.h17v03.006.2016184020251.hdf (4201160 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016173.h17v03.006.2016184020251.hdf (4201160 bytes) -> ✓
# Remote file: MCD15A3H.A2016173.h17v04.006.2016184033245.hdf (4928839 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016173.h17v04.006.2016184033245.hdf (4928839 bytes) -> ✓
# Remote file: MCD15A3H.A2016173.h18v03.006.2016184015826.hdf (9685133 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016173.h18v03.006.2016184015826.hdf (9685133 bytes) -> ✓
# Remote file: MCD15A3H.A2016173.h18v04.006.2016184015903.hdf (12508071 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016173.h18v04.006.2016184015903.hdf (12508071 bytes) -> ✓
# Remote file: MCD15A3H.A2016177.h17v03.006.2016184043337.hdf (4043112 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016177.h17v03.006.2016184043337.hdf (4043112 bytes) -> ✓
# Remote file: MCD15A3H.A2016177.h17v04.006.2016184043348.hdf (4950550 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016177.h17v04.006.2016184043348.hdf (4950550 bytes) -> ✓
# Remote file: MCD15A3H.A2016177.h18v03.006.2016184045617.hdf (10003400 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016177.h18v03.006.2016184045617.hdf (10003400 bytes) -> ✓
# Remote file: MCD15A3H.A2016177.h18v04.006.2016184044437.hdf (12777001 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016177.h18v04.006.2016184044437.hdf (12777001 bytes) -> ✓
# Remote file: MCD15A3H.A2016181.h17v03.006.2016189192722.hdf (4195129 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016181.h17v03.006.2016189192722.hdf (4195129 bytes) -> ✓
# Remote file: MCD15A3H.A2016181.h17v04.006.2016189192727.hdf (4709821 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016181.h17v04.006.2016189192727.hdf (4709821 bytes) -> ✓
# Remote file: MCD15A3H.A2016181.h18v03.006.2016189192744.hdf (8668825 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016181.h18v03.006.2016189192744.hdf (8668825 bytes) -> ✓
# Remote file: MCD15A3H.A2016181.h18v04.006.2016189192751.hdf (12541981 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016181.h18v04.006.2016189192751.hdf (12541981 bytes) -> ✓
# Remote file: MCD15A3H.A2016185.h17v03.006.2016190065600.hdf (3743221 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016185.h17v03.006.2016190065600.hdf (3743221 bytes) -> ✓
# Remote file: MCD15A3H.A2016185.h17v04.006.2016190064224.hdf (4890918 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016185.h17v04.006.2016190064224.hdf (4890918 bytes) -> ✓
# Remote file: MCD15A3H.A2016185.h18v03.006.2016190065408.hdf (10037850 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016185.h18v03.006.2016190065408.hdf (10037850 bytes) -> ✓
# Remote file: MCD15A3H.A2016185.h18v04.006.2016190064636.hdf (12612089 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016185.h18v04.006.2016190064636.hdf (12612089 bytes) -> ✓
# Remote file: MCD15A3H.A2016189.h17v03.006.2016194191636.hdf (3881846 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016189.h17v03.006.2016194191636.hdf (3881846 bytes) -> ✓
# Remote file: MCD15A3H.A2016189.h17v04.006.2016194191327.hdf (4881689 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016189.h17v04.006.2016194191327.hdf (4881689 bytes) -> ✓
# Remote file: MCD15A3H.A2016189.h18v03.006.2016194192007.hdf (9861838 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016189.h18v03.006.2016194192007.hdf (9861838 bytes) -> ✓
# Remote file: MCD15A3H.A2016189.h18v04.006.2016194192044.hdf (12434913 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016189.h18v04.006.2016194192044.hdf (12434913 bytes) -> ✓
# Remote file: MCD15A3H.A2016193.h17v03.006.2016198083739.hdf (4241871 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016193.h17v03.006.2016198083739.hdf (4241871 bytes) -> ✓
# Remote file: MCD15A3H.A2016193.h17v04.006.2016198083237.hdf (4949751 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016193.h17v04.006.2016198083237.hdf (4949751 bytes) -> ✓
# Remote file: MCD15A3H.A2016193.h18v03.006.2016198085248.hdf (9519473 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016193.h18v03.006.2016198085248.hdf (9519473 bytes) -> ✓
# Remote file: MCD15A3H.A2016193.h18v04.006.2016198083748.hdf (12233868 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016193.h18v04.006.2016198083748.hdf (12233868 bytes) -> ✓
# Remote file: MCD15A3H.A2016197.h17v03.006.2016204134529.hdf (3873377 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016197.h17v03.006.2016204134529.hdf (3873377 bytes) -> ✓
# Remote file: MCD15A3H.A2016197.h17v04.006.2016204134527.hdf (4686356 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016197.h17v04.006.2016204134527.hdf (4686356 bytes) -> ✓
# Remote file: MCD15A3H.A2016197.h18v03.006.2016204134521.hdf (9385279 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016197.h18v03.006.2016204134521.hdf (9385279 bytes) -> ✓
# Remote file: MCD15A3H.A2016197.h18v04.006.2016204134536.hdf (12418183 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016197.h18v04.006.2016204134536.hdf (12418183 bytes) -> ✓
# Remote file: MCD15A3H.A2016201.h17v03.006.2016207215017.hdf (4448004 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016201.h17v03.006.2016207215017.hdf (4448004 bytes) -> ✓
# Remote file: MCD15A3H.A2016201.h17v04.006.2016207215015.hdf (4831843 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016201.h17v04.006.2016207215015.hdf (4831843 bytes) -> ✓
# Remote file: MCD15A3H.A2016201.h18v03.006.2016207215333.hdf (9793420 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016201.h18v03.006.2016207215333.hdf (9793420 bytes) -> ✓
# Remote file: MCD15A3H.A2016201.h18v04.006.2016207215338.hdf (12339466 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016201.h18v04.006.2016207215338.hdf (12339466 bytes) -> ✓
# Remote file: MCD15A3H.A2016205.h17v03.006.2016222121935.hdf (3152755 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016205.h17v03.006.2016222121935.hdf (3152755 bytes) -> ✓
# Remote file: MCD15A3H.A2016205.h17v04.006.2016222121939.hdf (4851663 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016205.h17v04.006.2016222121939.hdf (4851663 bytes) -> ✓
# Remote file: MCD15A3H.A2016205.h18v03.006.2016222121947.hdf (9838750 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016205.h18v03.006.2016222121947.hdf (9838750 bytes) -> ✓
# Remote file: MCD15A3H.A2016205.h18v04.006.2016222121954.hdf (12818482 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016205.h18v04.006.2016222121954.hdf (12818482 bytes) -> ✓
# Remote file: MCD15A3H.A2016209.h17v03.006.2016222122240.hdf (4092933 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016209.h17v03.006.2016222122240.hdf (4092933 bytes) -> ✓
# Remote file: MCD15A3H.A2016209.h17v04.006.2016222122242.hdf (4671349 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016209.h17v04.006.2016222122242.hdf (4671349 bytes) -> ✓
# Remote file: MCD15A3H.A2016209.h18v03.006.2016222122251.hdf (9694363 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016209.h18v03.006.2016222122251.hdf (9694363 bytes) -> ✓
# Remote file: MCD15A3H.A2016209.h18v04.006.2016222122257.hdf (12804826 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016209.h18v04.006.2016222122257.hdf (12804826 bytes) -> ✓
# Remote file: MCD15A3H.A2016213.h17v03.006.2016239132222.hdf (3709552 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016213.h17v03.006.2016239132222.hdf (3709552 bytes) -> ✓
# Remote file: MCD15A3H.A2016213.h17v04.006.2016239132235.hdf (4933950 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016213.h17v04.006.2016239132235.hdf (4933950 bytes) -> ✓
# Remote file: MCD15A3H.A2016213.h18v03.006.2016239132253.hdf (9387503 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016213.h18v03.006.2016239132253.hdf (9387503 bytes) -> ✓
# Remote file: MCD15A3H.A2016213.h18v04.006.2016239132255.hdf (12617883 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016213.h18v04.006.2016239132255.hdf (12617883 bytes) -> ✓
# Remote file: MCD15A3H.A2016217.h17v03.006.2016239132333.hdf (4224793 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016217.h17v03.006.2016239132333.hdf (4224793 bytes) -> ✓
# Remote file: MCD15A3H.A2016217.h17v04.006.2016239132337.hdf (4778557 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016217.h17v04.006.2016239132337.hdf (4778557 bytes) -> ✓
# Remote file: MCD15A3H.A2016217.h18v03.006.2016239132341.hdf (9588798 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016217.h18v03.006.2016239132341.hdf (9588798 bytes) -> ✓
# Remote file: MCD15A3H.A2016217.h18v04.006.2016239132347.hdf (12531352 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016217.h18v04.006.2016239132347.hdf (12531352 bytes) -> ✓
# Remote file: MCD15A3H.A2016221.h17v03.006.2016239132432.hdf (4373925 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016221.h17v03.006.2016239132432.hdf (4373925 bytes) -> ✓
# Remote file: MCD15A3H.A2016221.h17v04.006.2016239132433.hdf (4893083 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016221.h17v04.006.2016239132433.hdf (4893083 bytes) -> ✓
# Remote file: MCD15A3H.A2016221.h18v03.006.2016239132435.hdf (10015616 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016221.h18v03.006.2016239132435.hdf (10015616 bytes) -> ✓
# Remote file: MCD15A3H.A2016221.h18v04.006.2016239132440.hdf (12694976 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016221.h18v04.006.2016239132440.hdf (12694976 bytes) -> ✓
# Remote file: MCD15A3H.A2016225.h17v03.006.2016239132521.hdf (4251114 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016225.h17v03.006.2016239132521.hdf (4251114 bytes) -> ✓
# Remote file: MCD15A3H.A2016225.h17v04.006.2016239132525.hdf (4660028 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016225.h17v04.006.2016239132525.hdf (4660028 bytes) -> ✓
# Remote file: MCD15A3H.A2016225.h18v03.006.2016239132527.hdf (9635512 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016225.h18v03.006.2016239132527.hdf (9635512 bytes) -> ✓
# Remote file: MCD15A3H.A2016225.h18v04.006.2016239132529.hdf (12269285 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016225.h18v04.006.2016239132529.hdf (12269285 bytes) -> ✓
# Remote file: MCD15A3H.A2016229.h17v03.006.2016239132612.hdf (4403658 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016229.h17v03.006.2016239132612.hdf (4403658 bytes) -> ✓
# Remote file: MCD15A3H.A2016229.h17v04.006.2016239132615.hdf (4833638 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016229.h17v04.006.2016239132615.hdf (4833638 bytes) -> ✓
# Remote file: MCD15A3H.A2016229.h18v03.006.2016239132614.hdf (9743099 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016229.h18v03.006.2016239132614.hdf (9743099 bytes) -> ✓
# Remote file: MCD15A3H.A2016229.h18v04.006.2016239132624.hdf (12491832 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016229.h18v04.006.2016239132624.hdf (12491832 bytes) -> ✓
# Remote file: MCD15A3H.A2016233.h17v03.006.2016239154552.hdf (4163108 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016233.h17v03.006.2016239154552.hdf (4163108 bytes) -> ✓
# Remote file: MCD15A3H.A2016233.h17v04.006.2016239160839.hdf (4766538 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016233.h17v04.006.2016239160839.hdf (4766538 bytes) -> ✓
# Remote file: MCD15A3H.A2016233.h18v03.006.2016239161901.hdf (9343436 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016233.h18v03.006.2016239161901.hdf (9343436 bytes) -> ✓
# Remote file: MCD15A3H.A2016233.h18v04.006.2016239154620.hdf (12005910 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016233.h18v04.006.2016239154620.hdf (12005910 bytes) -> ✓
# Remote file: MCD15A3H.A2016237.h17v03.006.2016243035304.hdf (4541491 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016237.h17v03.006.2016243035304.hdf (4541491 bytes) -> ✓
# Remote file: MCD15A3H.A2016237.h17v04.006.2016243035316.hdf (4724822 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016237.h17v04.006.2016243035316.hdf (4724822 bytes) -> ✓
# Remote file: MCD15A3H.A2016237.h18v03.006.2016243035317.hdf (9327872 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016237.h18v03.006.2016243035317.hdf (9327872 bytes) -> ✓
# Remote file: MCD15A3H.A2016237.h18v04.006.2016243035643.hdf (11760270 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016237.h18v04.006.2016243035643.hdf (11760270 bytes) -> ✓
# Remote file: MCD15A3H.A2016241.h17v03.006.2016246080654.hdf (4635178 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016241.h17v03.006.2016246080654.hdf (4635178 bytes) -> ✓
# Remote file: MCD15A3H.A2016241.h17v04.006.2016246080640.hdf (4848049 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016241.h17v04.006.2016246080640.hdf (4848049 bytes) -> ✓
# Remote file: MCD15A3H.A2016241.h18v03.006.2016246075613.hdf (9603618 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016241.h18v03.006.2016246075613.hdf (9603618 bytes) -> ✓
# Remote file: MCD15A3H.A2016241.h18v04.006.2016246075129.hdf (12457175 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016241.h18v04.006.2016246075129.hdf (12457175 bytes) -> ✓
# Remote file: MCD15A3H.A2016245.h17v03.006.2016250072631.hdf (4305485 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016245.h17v03.006.2016250072631.hdf (4305485 bytes) -> ✓
# Remote file: MCD15A3H.A2016245.h17v04.006.2016250072220.hdf (4826683 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016245.h17v04.006.2016250072220.hdf (4826683 bytes) -> ✓
# Remote file: MCD15A3H.A2016245.h18v03.006.2016250072631.hdf (9556216 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016245.h18v03.006.2016250072631.hdf (9556216 bytes) -> ✓
# Remote file: MCD15A3H.A2016245.h18v04.006.2016250072642.hdf (12274637 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016245.h18v04.006.2016250072642.hdf (12274637 bytes) -> ✓
# Remote file: MCD15A3H.A2016249.h17v03.006.2016263190209.hdf (4368897 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016249.h17v03.006.2016263190209.hdf (4368897 bytes) -> ✓
# Remote file: MCD15A3H.A2016249.h17v04.006.2016263190211.hdf (4671305 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016249.h17v04.006.2016263190211.hdf (4671305 bytes) -> ✓
# Remote file: MCD15A3H.A2016249.h18v03.006.2016263190217.hdf (9457762 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016249.h18v03.006.2016263190217.hdf (9457762 bytes) -> ✓
# Remote file: MCD15A3H.A2016249.h18v04.006.2016263190223.hdf (11997496 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016249.h18v04.006.2016263190223.hdf (11997496 bytes) -> ✓
# Remote file: MCD15A3H.A2016253.h17v03.006.2016263190229.hdf (4248687 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016253.h17v03.006.2016263190229.hdf (4248687 bytes) -> ✓
# Remote file: MCD15A3H.A2016253.h17v04.006.2016263190229.hdf (4727533 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016253.h17v04.006.2016263190229.hdf (4727533 bytes) -> ✓
# Remote file: MCD15A3H.A2016253.h18v03.006.2016263190242.hdf (9445573 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016253.h18v03.006.2016263190242.hdf (9445573 bytes) -> ✓
# Remote file: MCD15A3H.A2016253.h18v04.006.2016263190244.hdf (12228676 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016253.h18v04.006.2016263190244.hdf (12228676 bytes) -> ✓
# Remote file: MCD15A3H.A2016257.h17v03.006.2016265021317.hdf (4492946 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016257.h17v03.006.2016265021317.hdf (4492946 bytes) -> ✓
# Remote file: MCD15A3H.A2016257.h17v04.006.2016265021329.hdf (4749377 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016257.h17v04.006.2016265021329.hdf (4749377 bytes) -> ✓
# Remote file: MCD15A3H.A2016257.h18v03.006.2016265021755.hdf (9272851 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016257.h18v03.006.2016265021755.hdf (9272851 bytes) -> ✓
# Remote file: MCD15A3H.A2016257.h18v04.006.2016265021336.hdf (11981224 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016257.h18v04.006.2016265021336.hdf (11981224 bytes) -> ✓
# Remote file: MCD15A3H.A2016261.h17v03.006.2016267014113.hdf (4215392 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016261.h17v03.006.2016267014113.hdf (4215392 bytes) -> ✓
# Remote file: MCD15A3H.A2016261.h17v04.006.2016267013302.hdf (4801281 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016261.h17v04.006.2016267013302.hdf (4801281 bytes) -> ✓
# Remote file: MCD15A3H.A2016261.h18v03.006.2016267015350.hdf (9306634 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016261.h18v03.006.2016267015350.hdf (9306634 bytes) -> ✓
# Remote file: MCD15A3H.A2016261.h18v04.006.2016267013305.hdf (10804015 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016261.h18v04.006.2016267013305.hdf (10804015 bytes) -> ✓
# Remote file: MCD15A3H.A2016265.h17v03.006.2016274181912.hdf (4247257 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016265.h17v03.006.2016274181912.hdf (4247257 bytes) -> ✓
# Remote file: MCD15A3H.A2016265.h17v04.006.2016274181914.hdf (4760792 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016265.h17v04.006.2016274181914.hdf (4760792 bytes) -> ✓
# Remote file: MCD15A3H.A2016265.h18v03.006.2016274181913.hdf (9369718 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016265.h18v03.006.2016274181913.hdf (9369718 bytes) -> ✓
# Remote file: MCD15A3H.A2016265.h18v04.006.2016274181937.hdf (12322903 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016265.h18v04.006.2016274181937.hdf (12322903 bytes) -> ✓
# Remote file: MCD15A3H.A2016269.h17v03.006.2016274182007.hdf (4376992 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016269.h17v03.006.2016274182007.hdf (4376992 bytes) -> ✓
# Remote file: MCD15A3H.A2016269.h17v04.006.2016274182008.hdf (4858118 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2016269.h17v04.006.2016274182008.hdf (4858118 bytes) -> ✓
# ...
# Remote file: MCD15A3H.A2017285.h17v03.006.2017290125916.hdf (3468615 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017285.h17v03.006.2017290125916.hdf (3468615 bytes) -> ✓
# Remote file: MCD15A3H.A2017285.h17v04.006.2017290125918.hdf (4591504 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017285.h17v04.006.2017290125918.hdf (4591504 bytes) -> ✓
# Remote file: MCD15A3H.A2017285.h18v03.006.2017290125920.hdf (8896325 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017285.h18v03.006.2017290125920.hdf (8896325 bytes) -> ✓
# Remote file: MCD15A3H.A2017285.h18v04.006.2017290125934.hdf (11634598 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017285.h18v04.006.2017290125934.hdf (11634598 bytes) -> ✓
# Remote file: MCD15A3H.A2017289.h17v03.006.2017297190158.hdf (3760608 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017289.h17v03.006.2017297190158.hdf (3760608 bytes) -> ✓
# Remote file: MCD15A3H.A2017289.h17v04.006.2017297185846.hdf (4649831 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017289.h17v04.006.2017297185846.hdf (4649831 bytes) -> ✓
# Remote file: MCD15A3H.A2017289.h18v03.006.2017297185623.hdf (8440805 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017289.h18v03.006.2017297185623.hdf (8440805 bytes) -> ✓
# Remote file: MCD15A3H.A2017289.h18v04.006.2017297185318.hdf (11406745 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017289.h18v04.006.2017297185318.hdf (11406745 bytes) -> ✓
# Remote file: MCD15A3H.A2017293.h17v03.006.2017300140725.hdf (3944541 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017293.h17v03.006.2017300140725.hdf (3944541 bytes) -> ✓
# Remote file: MCD15A3H.A2017293.h17v04.006.2017300140731.hdf (4818565 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017293.h17v04.006.2017300140731.hdf (4818565 bytes) -> ✓
# Remote file: MCD15A3H.A2017293.h18v03.006.2017300140729.hdf (7024988 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017293.h18v03.006.2017300140729.hdf (7024988 bytes) -> ✓
# Remote file: MCD15A3H.A2017293.h18v04.006.2017300140745.hdf (11086522 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017293.h18v04.006.2017300140745.hdf (11086522 bytes) -> ✓
# Remote file: MCD15A3H.A2017297.h17v03.006.2017303194711.hdf (4246163 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017297.h17v03.006.2017303194711.hdf (4246163 bytes) -> ✓
# Remote file: MCD15A3H.A2017297.h17v04.006.2017303195107.hdf (4539427 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017297.h17v04.006.2017303195107.hdf (4539427 bytes) -> ✓
# Remote file: MCD15A3H.A2017297.h18v03.006.2017303194717.hdf (7442365 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017297.h18v03.006.2017303194717.hdf (7442365 bytes) -> ✓
# Remote file: MCD15A3H.A2017297.h18v04.006.2017303195020.hdf (11265959 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017297.h18v04.006.2017303195020.hdf (11265959 bytes) -> ✓
# Remote file: MCD15A3H.A2017301.h17v03.006.2017310191336.hdf (3919467 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017301.h17v03.006.2017310191336.hdf (3919467 bytes) -> ✓
# Remote file: MCD15A3H.A2017301.h17v04.006.2017310191339.hdf (4609934 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017301.h17v04.006.2017310191339.hdf (4609934 bytes) -> ✓
# Remote file: MCD15A3H.A2017301.h18v03.006.2017310191343.hdf (8344911 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017301.h18v03.006.2017310191343.hdf (8344911 bytes) -> ✓
# Remote file: MCD15A3H.A2017301.h18v04.006.2017310191349.hdf (11504686 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017301.h18v04.006.2017310191349.hdf (11504686 bytes) -> ✓
# Remote file: MCD15A3H.A2017305.h17v03.006.2017312184425.hdf (3722409 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017305.h17v03.006.2017312184425.hdf (3722409 bytes) -> ✓
# Remote file: MCD15A3H.A2017305.h17v04.006.2017312184421.hdf (4364979 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017305.h17v04.006.2017312184421.hdf (4364979 bytes) -> ✓
# Remote file: MCD15A3H.A2017305.h18v03.006.2017312184812.hdf (7391386 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017305.h18v03.006.2017312184812.hdf (7391386 bytes) -> ✓
# Remote file: MCD15A3H.A2017305.h18v04.006.2017312184820.hdf (11037062 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017305.h18v04.006.2017312184820.hdf (11037062 bytes) -> ✓
# Remote file: MCD15A3H.A2017309.h17v03.006.2017314035405.hdf (3686355 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017309.h17v03.006.2017314035405.hdf (3686355 bytes) -> ✓
# Remote file: MCD15A3H.A2017309.h17v04.006.2017314035345.hdf (4790373 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017309.h17v04.006.2017314035345.hdf (4790373 bytes) -> ✓
# Remote file: MCD15A3H.A2017309.h18v03.006.2017314035352.hdf (7245523 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017309.h18v03.006.2017314035352.hdf (7245523 bytes) -> ✓
# Remote file: MCD15A3H.A2017309.h18v04.006.2017314035353.hdf (9765354 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017309.h18v04.006.2017314035353.hdf (9765354 bytes) -> ✓
# Remote file: MCD15A3H.A2017313.h17v03.006.2017325161816.hdf (3453261 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017313.h17v03.006.2017325161816.hdf (3453261 bytes) -> ✓
# Remote file: MCD15A3H.A2017313.h17v04.006.2017325161820.hdf (4550041 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017313.h17v04.006.2017325161820.hdf (4550041 bytes) -> ✓
# Remote file: MCD15A3H.A2017313.h18v03.006.2017325161830.hdf (5712717 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017313.h18v03.006.2017325161830.hdf (5712717 bytes) -> ✓
# Remote file: MCD15A3H.A2017313.h18v04.006.2017325161833.hdf (7419217 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017313.h18v04.006.2017325161833.hdf (7419217 bytes) -> ✓
# Remote file: MCD15A3H.A2017317.h17v03.006.2017331160711.hdf (2973621 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017317.h17v03.006.2017331160711.hdf (2973621 bytes) -> ✓
# Remote file: MCD15A3H.A2017317.h17v04.006.2017331160712.hdf (4673163 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017317.h17v04.006.2017331160712.hdf (4673163 bytes) -> ✓
# Remote file: MCD15A3H.A2017317.h18v03.006.2017331160709.hdf (6767095 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017317.h18v03.006.2017331160709.hdf (6767095 bytes) -> ✓
# Remote file: MCD15A3H.A2017317.h18v04.006.2017331160715.hdf (10970240 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017317.h18v04.006.2017331160715.hdf (10970240 bytes) -> ✓
# Remote file: MCD15A3H.A2017321.h17v03.006.2017331211621.hdf (2821846 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017321.h17v03.006.2017331211621.hdf (2821846 bytes) -> ✓
# Remote file: MCD15A3H.A2017321.h17v04.006.2017331211453.hdf (4513037 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017321.h17v04.006.2017331211453.hdf (4513037 bytes) -> ✓
# Remote file: MCD15A3H.A2017321.h18v03.006.2017331211508.hdf (6234278 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017321.h18v03.006.2017331211508.hdf (6234278 bytes) -> ✓
# Remote file: MCD15A3H.A2017321.h18v04.006.2017331211501.hdf (10041105 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017321.h18v04.006.2017331211501.hdf (10041105 bytes) -> ✓
# Remote file: MCD15A3H.A2017325.h17v03.006.2017333160951.hdf (2934082 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017325.h17v03.006.2017333160951.hdf (2934082 bytes) -> ✓
# Remote file: MCD15A3H.A2017325.h17v04.006.2017333160942.hdf (4405628 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017325.h17v04.006.2017333160942.hdf (4405628 bytes) -> ✓
# Remote file: MCD15A3H.A2017325.h18v03.006.2017333160920.hdf (5489995 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017325.h18v03.006.2017333160920.hdf (5489995 bytes) -> ✓
# Remote file: MCD15A3H.A2017325.h18v04.006.2017333160922.hdf (10381825 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017325.h18v04.006.2017333160922.hdf (10381825 bytes) -> ✓
# Remote file: MCD15A3H.A2017329.h17v03.006.2017334154337.hdf (2997328 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017329.h17v03.006.2017334154337.hdf (2997328 bytes) -> ✓
# Remote file: MCD15A3H.A2017329.h17v04.006.2017334154340.hdf (4674211 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017329.h17v04.006.2017334154340.hdf (4674211 bytes) -> ✓
# Remote file: MCD15A3H.A2017329.h18v03.006.2017334154339.hdf (5753505 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017329.h18v03.006.2017334154339.hdf (5753505 bytes) -> ✓
# Remote file: MCD15A3H.A2017329.h18v04.006.2017334154345.hdf (9714566 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017329.h18v04.006.2017334154345.hdf (9714566 bytes) -> ✓
# Remote file: MCD15A3H.A2017333.h17v03.006.2017341183030.hdf (2936938 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017333.h17v03.006.2017341183030.hdf (2936938 bytes) -> ✓
# Remote file: MCD15A3H.A2017333.h17v04.006.2017341183224.hdf (4579436 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017333.h17v04.006.2017341183224.hdf (4579436 bytes) -> ✓
# Remote file: MCD15A3H.A2017333.h18v03.006.2017341183458.hdf (5787421 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017333.h18v03.006.2017341183458.hdf (5787421 bytes) -> ✓
# Remote file: MCD15A3H.A2017333.h18v04.006.2017341183037.hdf (9130769 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017333.h18v04.006.2017341183037.hdf (9130769 bytes) -> ✓
# Remote file: MCD15A3H.A2017337.h17v03.006.2017342030946.hdf (2648155 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017337.h17v03.006.2017342030946.hdf (2648155 bytes) -> ✓
# Remote file: MCD15A3H.A2017337.h17v04.006.2017342030858.hdf (4403771 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017337.h17v04.006.2017342030858.hdf (4403771 bytes) -> ✓
# Remote file: MCD15A3H.A2017337.h18v03.006.2017342030824.hdf (5516451 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017337.h18v03.006.2017342030824.hdf (5516451 bytes) -> ✓
# Remote file: MCD15A3H.A2017337.h18v04.006.2017342030439.hdf (8642262 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017337.h18v04.006.2017342030439.hdf (8642262 bytes) -> ✓
# Remote file: MCD15A3H.A2017341.h17v03.006.2017346032258.hdf (2872871 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017341.h17v03.006.2017346032258.hdf (2872871 bytes) -> ✓
# Remote file: MCD15A3H.A2017341.h17v04.006.2017346031815.hdf (3772921 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017341.h17v04.006.2017346031815.hdf (3772921 bytes) -> ✓
# Remote file: MCD15A3H.A2017341.h18v03.006.2017346032329.hdf (5764313 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017341.h18v03.006.2017346032329.hdf (5764313 bytes) -> ✓
# Remote file: MCD15A3H.A2017341.h18v04.006.2017346031740.hdf (9202111 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017341.h18v04.006.2017346031740.hdf (9202111 bytes) -> ✓
# Remote file: MCD15A3H.A2017345.h17v03.006.2017353214417.hdf (2841799 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017345.h17v03.006.2017353214417.hdf (2841799 bytes) -> ✓
# Remote file: MCD15A3H.A2017345.h17v04.006.2017353214204.hdf (4227545 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017345.h17v04.006.2017353214204.hdf (4227545 bytes) -> ✓
# Remote file: MCD15A3H.A2017345.h18v03.006.2017353215001.hdf (4974361 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017345.h18v03.006.2017353215001.hdf (4974361 bytes) -> ✓
# Remote file: MCD15A3H.A2017345.h18v04.006.2017353214523.hdf (8105678 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017345.h18v04.006.2017353214523.hdf (8105678 bytes) -> ✓
# Remote file: MCD15A3H.A2017349.h17v03.006.2017354030323.hdf (2806841 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017349.h17v03.006.2017354030323.hdf (2806841 bytes) -> ✓
# Remote file: MCD15A3H.A2017349.h17v04.006.2017354030754.hdf (4363732 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017349.h17v04.006.2017354030754.hdf (4363732 bytes) -> ✓
# Remote file: MCD15A3H.A2017349.h18v03.006.2017354031001.hdf (5676597 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017349.h18v03.006.2017354031001.hdf (5676597 bytes) -> ✓
# Remote file: MCD15A3H.A2017349.h18v04.006.2017354030436.hdf (8710056 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017349.h18v04.006.2017354030436.hdf (8710056 bytes) -> ✓
# Remote file: MCD15A3H.A2017353.h17v03.006.2017361223000.hdf (2454804 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017353.h17v03.006.2017361223000.hdf (2454804 bytes) -> ✓
# Remote file: MCD15A3H.A2017353.h17v04.006.2017361223126.hdf (4268793 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017353.h17v04.006.2017361223126.hdf (4268793 bytes) -> ✓
# Remote file: MCD15A3H.A2017353.h18v03.006.2017361223009.hdf (4838382 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017353.h18v03.006.2017361223009.hdf (4838382 bytes) -> ✓
# Remote file: MCD15A3H.A2017353.h18v04.006.2017361223133.hdf (7475584 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017353.h18v04.006.2017361223133.hdf (7475584 bytes) -> ✓
# Remote file: MCD15A3H.A2017357.h17v03.006.2018002133710.hdf (2742541 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017357.h17v03.006.2018002133710.hdf (2742541 bytes) -> ✓
# Remote file: MCD15A3H.A2017357.h17v04.006.2018002133721.hdf (4124127 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017357.h17v04.006.2018002133721.hdf (4124127 bytes) -> ✓
# Remote file: MCD15A3H.A2017357.h18v03.006.2018002133701.hdf (4524338 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017357.h18v03.006.2018002133701.hdf (4524338 bytes) -> ✓
# Remote file: MCD15A3H.A2017357.h18v04.006.2018002133807.hdf (8570149 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017357.h18v04.006.2018002133807.hdf (8570149 bytes) -> ✓
# Remote file: MCD15A3H.A2017361.h17v03.006.2018002204120.hdf (2892428 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017361.h17v03.006.2018002204120.hdf (2892428 bytes) -> ✓
# Remote file: MCD15A3H.A2017361.h17v04.006.2018002204315.hdf (4336283 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017361.h17v04.006.2018002204315.hdf (4336283 bytes) -> ✓
# Remote file: MCD15A3H.A2017361.h18v03.006.2018002204108.hdf (5513072 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017361.h18v03.006.2018002204108.hdf (5513072 bytes) -> ✓
# Remote file: MCD15A3H.A2017361.h18v04.006.2018002204003.hdf (7857083 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017361.h18v04.006.2018002204003.hdf (7857083 bytes) -> ✓
# Remote file: MCD15A3H.A2017365.h17v03.006.2018005032624.hdf (2852422 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017365.h17v03.006.2018005032624.hdf (2852422 bytes) -> ✓
# Remote file: MCD15A3H.A2017365.h17v04.006.2018005032653.hdf (3796797 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017365.h17v04.006.2018005032653.hdf (3796797 bytes) -> ✓
# Remote file: MCD15A3H.A2017365.h18v03.006.2018005032348.hdf (5413603 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017365.h18v03.006.2018005032348.hdf (5413603 bytes) -> ✓
# Remote file: MCD15A3H.A2017365.h18v04.006.2018005032627.hdf (8959434 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2017365.h18v04.006.2018005032627.hdf (8959434 bytes) -> ✓
# Remote file: MCD15A3H.A2018273.h17v03.006.2018278143630.hdf (4144535 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2018273.h17v03.006.2018278143630.hdf (4144535 bytes) -> ✓
# Remote file: MCD15A3H.A2018273.h17v04.006.2018278143630.hdf (4663455 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2018273.h17v04.006.2018278143630.hdf (4663455 bytes) -> ✓
# Remote file: MCD15A3H.A2018273.h18v03.006.2018278143633.hdf (9136806 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2018273.h18v03.006.2018278143633.hdf (9136806 bytes) -> ✓
# Remote file: MCD15A3H.A2018273.h18v04.006.2018278143638.hdf (11610036 bytes) -> /Users/plewis/Data/geog0111/data/MCD15A3H.A2018273.h18v04.006.2018278143638.hdf (11610036 bytes) -> ✓

# %%
# Some imports that might be useful...
# Put them at the top so they're easy to find
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import sys
import os
from pathlib import Path
import gdal
from datetime import datetime, timedelta


def find_mcdfiles(year, doy, tiles, folder):
    data_folder = Path(folder)
    # Find all MCD files
    mcd_files = []
    for tile in tiles:
        sel_files = data_folder.glob(
            f"MCD15*.A{year:d}{doy:03d}.{tile:s}.*hdf")
        for fich in sel_files:
            mcd_files.append(fich)
    return mcd_files


def create_gdal_friendly_names(filenames, layer):

    # Create GDAL friendly-names...
    gdal_filenames = []
    for file_name in filenames:
        fname = f'HDF4_EOS:EOS_GRID:'+\
                    f'"{file_name.as_posix()}":'+\
                    f'MOD_Grid_MCD15A3H:{layer:s}'

        gdal_filenames.append(fname)
    return gdal_filenames



def mosaic_and_clip(tiles,
                    doy,
                    year,
                    folder="data/",
                    layer="Lai_500m",
                    shpfile="data/TM_WORLD_BORDERS-0.3.shp",
                    country_code="LU",
                    frmat="MEM"):
    """
    #TODO docstring missing!!!!
    """

    folder_path = Path(folder)
    # Find all files to mosaic together
    hdf_files = find_mcdfiles(year, doy, tiles, folder)

    # Create GDAL friendly-names...
    gdal_filenames = create_gdal_friendly_names(hdf_files, layer)
    if frmat == "MEM":
        g = gdal.Warp(
            "",
            gdal_filenames,
            format="MEM",
            dstNodata=255,
            cutlineDSName=shpfile,
            cutlineWhere=f"FIPS='{country_code:s}'",
            cropToCutline=True)
        data = g.ReadAsArray()
        return data
    elif frmat == "GTiff":
        geotiff_fnamex = f"{layer:s}_{year:d}_{doy:03d}_{country_code:s}.tif"
        geotiff_fname  = folder_path/geotiff_fnamex
        g = gdal.Warp(
            geotiff_fname.as_posix(),
            gdal_filenames,
            format=frmat,
            dstNodata=255,
            cutlineDSName=shpfile,
            cutlineWhere=f"FIPS='{country_code:s}'",
            cropToCutline=True)
        return geotiff_fname.as_posix()
    else:
        raise ValueError("Only MEM or GTiff formats supported!")
        
        
def process_single_date(tiles,
                    doy,
                    year,
                    folder="data/",
                    shpfile="data/TM_WORLD_BORDERS-0.3.shp",
                    country_code="LU",
                    frmat="MEM"):
    
    lai_data = mosaic_and_clip(tiles,
                    doy,
                    year,
                    folder=folder,
                    layer="Lai_500m",
                    shpfile=shpfile,
                    country_code=country_code,
                    frmat="MEM")*0.1
    # Note the scaling!
    
    qa_data = mosaic_and_clip(tiles,
                    doy,
                    year,
                    folder=folder,
                    layer="FparLai_QC",
                    shpfile=shpfile,
                    country_code=country_code,
                    frmat="MEM")
    sfc_qa = get_sfc_qc(qa_data)
    
    weights = get_scaling(sfc_qa)
    return lai_data, weights

from datetime import datetime, timedelta


def process_timeseries(year,
                       tiles,
                       folder,
                       shpfile,
                       country_code,
                       verbose=True):

    today = datetime(year, 1, 1)
    dates = []
    for i in range(92):
        if (i%10 == 0) and verbose:
            print(f"Doing {str(today):s}")
        if today.year != year:
            break
        doy = int(today.strftime("%j"))

        this_lai, this_weight = process_single_date(
            tiles,
            doy,
            year,
            folder=folder,
            shpfile=shpfile,
            country_code=country_code,
            frmat="MEM")
        if doy == 1:
            # First day, create outputs!
            ny, nx = this_lai.shape
            lai_array = np.zeros((ny, nx, 92))
            weights_array = np.zeros((ny, nx, 92))
        lai_array[:, :, i] = this_lai
        weights_array[:, :, i] = this_weight
        dates.append(today)
        today = today + timedelta(days=4)
    return dates, lai_array, weights_array

# %%
from ecmwfapi import ECMWFDataServer
server = ECMWFDataServer() 
from datetime import datetime, timedelta
starting = datetime(2017,1,1)
for one_day in range(53, 100):
    this_date = (starting + timedelta(days = one_day)).strftime('%Y-%m-%d')
    server.retrieve({
        "class": "mc",
        "dataset": "cams_nrealtime",
        "date": "%s"%this_date,
        "expver": "0001",
        "levtype": "sfc",
        "param": "137.128/206.210/207.210/209.210/210.210/211.210/212.210",
        "step": "0/3/6/9/12/15/18/21/24",
        "stream": "oper",
        "time": "00:00:00",
        "type": "fc",
        "grid": "0.125/0.125",
        "area": "90/-180/-90/180",
        "format":"netcdf",
        "target": "%s.nc"%this_date,
    })
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-75ac9615a11d> in <module>
# ----> 1 from ecmwfapi import ECMWFDataServer
#       2 server = ECMWFDataServer()
#       3 from datetime import datetime, timedelta
#       4 starting = datetime(2017,1,1)
#       5 for one_day in range(53, 100):
#
# ModuleNotFoundError: No module named 'ecmwfapi'

# %% [markdown]
# # Model calibration

# %% [markdown]
# As an addition  to the notes on function fitting, we consider the ideas of function fitting and model calibration in a bit more detail.
#
# We start with the example of a 'phenology' model as in the previous exercise:

# %% [markdown]
# ![](http://www2.geog.ucl.ac.uk/~plewis/geogg124/_images/zhang1.png)
#
# We consider a signal (e.g. NDVI) observational data.

# %%
'''
    which tile and year?
'''
tiles = []
for h in [17, 18]:
    for v in [3, 4]:
        tiles.append(f"h{h:02d}v{v:02d}")

year = 2017

dates, lai_array, weights_array = process_timeseries(
    year,
    tiles,
    folder="data/",
    shpfile="data/TM_WORLD_BORDERS-0.3.shp",
    country_code="NL")

# %%
import glob
year = 2005
tile = "h17v03"
# test it
# Search for all the files using wildcards
filelist = glob.glob ("data/MCD15A2.A{}*{}*.hdf".format(year, tile))
filelist.sort()
lai = read_lai(filelist,country='Ireland')
data = np.array(lai['Lai_1km'])
sd = np.array(lai['LaiStdDev_1km'])

# fix uncertainties
thresh = 0.25
sd[sd<thresh] = thresh

# %% [markdown]
# and consider a logistic function that we would like to use as a model of LAI development (phenology).
#
# A (double) logistic function is:
#
# $$
#  \hat{y} = p_0 - p_1 \left( \frac{1}{1 + e^{p_2 (t - p_3)}} + \frac{1}{1 + e^{p_4 (t - p_5)}} -1\right)
# $$

# %%
def dbl_logistic_model ( p, t ):
        """
            A double logistic model, as in Sobrino and Juliean, 
            or Zhang et al
            
            Parameters:, and rough guess
              
            p[0]=  ymean - 1.151*ysd  # minimum  (1.151 is 75% CI)
            p[1] = 2*1.151*ysd        # range
            p[2] = 0.19               # related to up slope
            p[3] = 120                # midpoint of up slope
            p[4] = 0.13               # related to down slope
            p[5] = 220                # midpoint of down slope
        """
        return p[0] - p[1]* ( 1./(1+np.exp(p[2]*(t-p[3]))) + \
                              1./(1+np.exp(-p[4]*(t-p[5])))  - 1 )

# %%
# test pixel
r = 442
c = 84

'''
    set up x and y data for a pixel
'''

y = data[:,r,c]
mask = np.logical_not(np.isnan(y))
y = np.array(y[mask])
x = (np.arange(46)*8+1.)[mask]
unc = np.array(sd[:,r,c][mask])
x_full = np.arange(1,366) 

# some stats on y for rough guesses
ysd = np.std(y)
ymean = np.mean(y)

# some rough guesses at the parameters
p = np.array([ymean - 1.151*ysd,2*1.151*ysd,0.1,120,0.1,240])

'''

Run the logistic model with these parameters

'''
y_hat = dbl_logistic_model(p,x_full)

plt.clf()
plt.plot(x_full,y_hat)
plt.plot(x,y,'*')
plt.errorbar(x,y,unc*1.96)

# %% [markdown]
# We can now calculate the residuals. We weight the residuals by the uncertainty, to normalise and express them in 'standard deviation' units.

# %%
def mismatch_function(p, x, y, unc):
    '''
    
    return the residuals 
    weighted by uncertainty
    
    '''
    y_hat = dbl_logistic_model(p, x)
    diff = (y_hat - y)/unc
    return diff

Z = mismatch_function(p,x,y,unc)

plt.plot([1,365.],[0,0.],'k-')
plt.xlim(0,365)
plt.plot(x,Z,'*')

print 'mean Z^2 =',(Z**2).mean()

# %% [markdown]
# ## Defining and implementing a cost function

# %% [markdown]
# More formally, consider the observations (i.e. LAI) as Gaussian distributions $y_{obs}(x)$ ~ $N(\bar{y}(x),C_{obs}(x))$ where $,C_{obs}(x)$ is the variance/covariance matrix (uncertainty) in the LAI observations at time $x$ and $\bar{y}$ its mean.
#
# We assume zero covariance between the errors at each observation, so $C_{obs}(x)$ is a diagonal matrix:
#
# $
# C_{obs} =
# \left( \begin{array}{ccc}
# \sigma^2_0 & 0 & ... & 0 \\
# 0 & \sigma^2_1 & ... & 0 \\
# \vdots & \vdots & \ddots & \vdots\\
# 0 & 0 & ... & \sigma^2_{n-1} \end{array} \right)
# $
#
# over $n$ samples (in $x$) and $\sigma^2_i$ is the variance of the $i^{th}$ sample (i.e. at $x_i$).
#
# We note that calculating the inverse of this matrix is trivial:
#
# $
# C_{obs}^{-1} =
# \left( \begin{array}{ccc}
# \frac{1}{\sigma^2_0} & 0 & ... & 0 \\
# 0 & \frac{1}{\sigma^2_1} & ... & 0 \\
# \vdots & \vdots & \ddots & \vdots\\
# 0 & 0 & ... & \frac{1}{\sigma^2_{n-1}} \end{array} \right)
# $
#
#
# Suppose now that we have a *model*:
#
# $
# \hat{y} = f(x,p)
# $
#
# where $p$ is a set of parameters of the function.
#
# We wish to obtain an *optimal* estimate of $p$, conditioned on the observations.
#
# We can do this by considering a *cost function*, $J_{obs}(y_{obs},p)$:
#
# $
# J_{obs}(y_{obs},p) = \frac{1}{2} \left[ y(x) - \hat{y}(x,p) \right]^T C_{obs}^{-1}  \left[ y(x) - \hat{y}(x,p) \right]
# $
#
# where $^T$ denotes the transpose operation.
#
# We could implement a general cost function of this sort as:

# %%
def J_obs(p, x, y, C1,
                      model=dbl_logistic_model):
    '''
    
    return 'cost' J
    
    p    : set (vector) of parameters
    x    : sample locations
    y    : function value at sample locations
    C1   : inverse variance /covariance matrix
        
    '''
    y_hat = model(p, x)
    
    diff = np.matrix(y_hat - y).T
    
    return 0.5 * np.array(diff.T * C1 * diff).flatten()[0]


# calculate the inverse var/covar matrix
# NB use np matrix here
# .I gives the inverse

C1 = np.matrix(np.diag(unc**2)).I

Z = J_obs(p,x,y,C1)

print Z

# %% [markdown]
# But since we only want to consider a diagonal uncertainty matrix here, it is simpler and faster to use:

# %%
def J_obs_fast(p, x, y, sd,\
                      model=dbl_logistic_model):
    '''
    
    return 'cost' J
    
    p    : set (vector) of parameters
    x    : sample locations
    y    : function value at sample locations
    sd   : uncertainty standard deviation
        
    '''
    y_hat = model(p, x)
    
    diff = (y_hat - y)/sd
    
    return 0.5 * (diff*diff).sum()


Z = J_obs_fast(p,x,y,unc)

print Z

# %% [markdown]
# Or ... we could design a function that could do either:

# %%
def J_obs(p, x, y, sd,\
                      model=dbl_logistic_model):
    '''
    
    return 'cost' J
    
    p    : set (vector) of parameters
    x    : sample locations
    y    : function value at sample locations
    sd   : uncertainty standard deviation
           *or* if not same shape as y, then
           assumed to be C1 (inverse var/covar matrix)
        
    '''
    y_hat = model(p, x)

    if sd.shape == y.shape:
        diff = (y_hat - y)/sd
        J = 0.5 * (diff*diff).sum()
    else:
        diff = np.matrix(y_hat - y).T
        J = 0.5 * np.array(diff.T * C1 * diff).flatten()[0]
    
    return J

C1 = np.matrix(np.diag(unc**2)).I

print J_obs(p,x,y,unc)
print J_obs(p,x,y,C1)

# %% [markdown]
# Notice that in this example, we can change the model used for calculating $\hat{y}$ (providing we use the same *interface*):

# %%
# cost using logistic model
print J_obs(p,x,y,unc,model=dbl_logistic_model)

# define another model

def sincos(p,x):
    '''
    
    y_hat = p[0] + p[1] sin(t) + p[2] cos(t)
   
    '''
    # put x in range 0 to 2 pi and call it t
    t = np.pi * 2 * x/365.25
    return p[0]*np.sin(t) + p[1] * np.cos(t)

# calculate the cost for this
p2 = [0.1,0.2,0.2]
print J_obs(p2,x,y,unc,model=sincos)

# %% [markdown]
# Note that the 2 models we have chosen here have rather different meanings for the parameters. Indeed, the logistic takes 6 parameters (in `p`) but the `sincos` function, only 3.

# %% [markdown]
# ## Solving for optimal estimate

# %% [markdown]
# Now, consider how Z varies as we vary `p`:

# %%
# vary the first parameter

pvals = np.mgrid[0.0:1.01:0.01]
mse   = np.zeros_like(pvals)
p_ = p.copy()
print p

for i,p0 in enumerate(pvals):
    p_[0] = p0
    Z = J_obs(p_,x,y,unc,model=dbl_logistic_model)
    mse[i] = (Z**2).mean()

# %%
plt.plot(pvals,np.sqrt(mse))
plt.xlabel('p0')
plt.ylabel('rmse')

# %% [markdown]
# We can consider this a 'slice' through an 'error surface' or 'cost function'.
#
# We can define the 'optimal' estimate of the parameter vector `p` as the set of `p` values that gives a *minimum* in the error surface, i.e. one for which:
#
# $
# \frac{\partial{J}}{\partial{p}} = 0
# $
#
# i.e. the rate of change of the error function is zero (in all dimensions).
#
# The function $J$ in this case is 6 dimensional. It is quite hard to visualise that, but we can easily examine two dimensions.

# %%
# vary the first 2 parameters

pvals = np.mgrid[0.0:2.01:0.01,0.0:3.51:0.01]
mse   = np.zeros_like(pvals[0])
p_ = p.copy()

for i in xrange(pvals.shape[1]):
    for j in xrange(pvals.shape[2]):
        for k in xrange(pvals.shape[0]):
            p_[k] = pvals[k,i,j]
            Z = J_obs(p_,x,y,unc,model=dbl_logistic_model)
            mse[i,j] = (Z**2).mean()

# %%
plt.figure(figsize=(10,10))
plt.imshow ( np.sqrt(mse), interpolation='nearest', extent=(0, 3.5, 0, 2.), origin="lower",
           cmap=plt.cm.BuPu_r)
plt.colorbar(orientation="horizontal", shrink=0.7)
cs = plt.contour( pvals[1], pvals[0], np.sqrt(mse), [50, 100, 150, 200, 400, 600])
plt.clabel(cs, fmt = '%2.1f', fontsize=8)

# %% [markdown]
# In both the one and two dimensional 'slices' we can quite easily spot the minimum of the error function. Remember that this is *only* for a particular set of values of the parameters that we do not vary here.

# %% [markdown]
# ## Look up table

# %% [markdown]
# One approach to finding the global minimum would be to simply calculate $J$ at some set of points (e.g. on a six dimensional grid), and to see which point showed the minimum of $J$. We can do this here:

# %%
'''
 recall the meaning of the parameters for the model we are using

 p[0]=  ymean - 1.151*ysd  # minimum  (1.151 is 75% CI) of LAI
 p[1] = 2*1.151*ysd        # range of LAI
 p[2] = 0.19               # related to up slope
 p[3] = 120                # midpoint of up slope
 p[4] = 0.13               # related to down slope
 p[5] = 220                # midpoint of down slope

'''

# consider parameter bounds

b = np.array([(0.01,10.),(0.01,10.),(0.01,1.),\
                  (50.,300.),(0.01,1.),(50.,300.)])

# number of samples per dimension (+1)
N = 5

# work out what steps to use over the grid
s = [(bound[1]-bound[0])/float(N) for bound in b]
# form a grid of samples over parameter space

pvals = np.mgrid[b[0,0]:b[0,1]+s[0]:s[0],\
                 b[1,0]:b[1,1]+s[1]:s[1],\
                 b[2,0]:b[2,1]+s[2]:s[2],\
                 b[3,0]:b[3,1]+s[3]:s[3],\
                 b[4,0]:b[4,1]+s[4]:s[4],\
                 b[5,0]:b[5,1]+s[5]:s[5]]

# set sse default to high
sse   = np.zeros_like(pvals[0]) + 1e20
p_ = p.copy()

print 'the grid shape is',pvals.shape
print 'the LUT grid has',pvals.size,'entries'

for i0 in xrange(pvals.shape[1]):
  for i1 in xrange(pvals.shape[2]):
    for i2 in xrange(pvals.shape[3]):
      for i3 in xrange(pvals.shape[4]):
        for i4 in xrange(pvals.shape[5]):
          for i5 in xrange(pvals.shape[6]):

            for k in xrange(pvals.shape[0]):
              p_[k] = pvals[k,i0,i1,i2,i3,i4,i5]
              
              try:
                Z = J_obs(p_,x,y,unc,model=dbl_logistic_model)
                sse[i0,i1,i2,i3,i4,i5] = (Z**2).sum()
              except:
                pass

# %% [markdown]
# but this takes a relatively long time, *even* if we use a really coarse grid as in this example (with a few hundred thousand samples).
#
# That said, LUT inversion is a pragmatic response to trying to find an optimal solution for the parameters when fitting a model. It is viable in low dimensional space, but becomes problematic as the number of dimensions increases.
#
# Note also that, as it stands, it can only provide a rough estimate of the parameters:

# %%
'''

Seek the minimum SSE

'''
# find the minimum value over the grid
minSSE = np.min(sse)
print 'the minimum value is',minSSE

# find where that occurs
w = np.where(sse == minSSE )
print '\nthe min is at sample',w

# a bit awkward to pull this out but it is possible
result = np.array(pvals[:,w[0],w[1],w[2],w[3],w[4],w[5]]).T[0]

print '\nthe result is',result

# %%
# actually, we would typically use np.argmin
# for this

minsamp = np.argmin(np.array(sse))

# now extract that for each parameter
result = np.array([pvals[i].flatten()[minsamp] \
                   for i in xrange(pvals.shape[0])])

print '\nthe result is',result 

# so we see we get the same result, whichever approach we take

# %% [markdown]
# If we now plot the data and model with these parameters:

# %%
y_hat = dbl_logistic_model(result,x_full)

plt.plot(x_full,y_hat)
plt.plot(x,y,'*')
plt.errorbar(x,y,unc*1.96)

# %% [markdown]
# we can see that it is not a bad effort (in that it broadly describes the data), but we do not know whether a 'better' (lower J) solution could have been obtained in between the grid points.

# %% [markdown]
# ### A faster LUT
#
# In the code snippet above, when creating the LUT, we can see that we have many nested loops. Generally speaking, this is a bad idea. We have also seen that the code is very slow. We can try to do the same here using some tricks to speed things up. In Python (as well as R, and to some extent, matlab and others), speed is usually hampered by having lots of ntested loops. We can usually do away with them.
#
# One way of creating a LUT efficiently is to note that if we have the same sample points along each dimension, the LUT is just the *cartesian product* of the (in this case 6) different dimensions. Here's the cartesian product for two dimensions:
# <p><a href="https://commons.wikimedia.org/wiki/File:Cartesian_Product_qtl1.svg#/media/File:Cartesian_Product_qtl1.svg"><img src="https://upload.wikimedia.org/wikipedia/commons/4/4e/Cartesian_Product_qtl1.svg" alt="Cartesian Product qtl1.svg" height="145" width="191"></a><br>By <a href="//commons.wikimedia.org/wiki/User:Quartl" title="User:Quartl">Quartl</a> - <span class="int-own-work" lang="en">Own work</span>, <a href="http://creativecommons.org/licenses/by-sa/3.0" title="Creative Commons Attribution-Share Alike 3.0">CC BY-SA 3.0</a>, <a href="https://commons.wikimedia.org/w/index.php?curid=22436861">Link</a></p>
#
# The Python [itertools](http://jmduke.com/posts/a-gentle-introduction-to-itertools/) module has this functionality implemented in the [`product`](https://docs.python.org/2/library/itertools.html#itertools.product) method. So we just need to create one list or array per dimension with the sampling points, and then use `itertools.product` to create our LUT.
#
# We can then use the python `map` method, which applies each element in an iterator (e.g. each row of the LUT) to a function. The function can only take  one parameter, so we have to *alias* `J_obs` using a `lambda` function that fixes the additional parameters in the function call. The result of this is an array with the cost associated with each parameter set in the LUT.
#
# We can use the `argmin` method to find the location of the minimum, and then use that position in the LUT array to get the parameters that get the best result.

# %%
# The parameter boundaries
b = np.array([(0.01,10.),(0.01,10.),(0.01,1.),
                  (50.,300.),(0.01,1.),(50.,300.)])
print b.shape
import itertools

n_samples =10 # 5 samples by dimension
pre_lut = np.zeros((6,n_samples)) # For each dimension, we store one vector with n_samples
for i in xrange(6):
    pre_lut[i,:] = np.linspace ( b[i,0], b[i,1], n_samples)
    
# Generates the LUT by doing a cartesian product of the 6 dimensions
LUT = [xx for xx in itertools.product ( pre_lut[0], pre_lut[1], 
                                       pre_lut[2], pre_lut[3], pre_lut[4], pre_lut[5])]
LUT = np.array(LUT) # Convert to array
print LUT.shape

# Calculate the cost function

cost_f = lambda pp: J_obs(pp,x,y,unc,model=dbl_logistic_model)**2 
cost = map (cost_f, LUT)
cost = np.array (cost)
iloc = cost.argmin()
print cost[iloc]
print LUT[iloc, :]
y_hat = dbl_logistic_model(LUT[iloc,:],x_full)

plt.plot(x_full,y_hat)
plt.plot(x,y,'*')
plt.errorbar(x,y,unc*1.96)

# %% [markdown]
# One interesting observation is that most of the time is spend evaluating the cost function (the creating of the LUT is quite fast), and that most modern computers have several CPUs. The calculation of the cost function for each element of the LUT is completely independent (the calculation of element 1 and element 100 is completely independent). We could evaluate these functions *in parallel*. To do that, we can use the [`multiprocessing`](https://pymotw.com/2/multiprocessing/basics.html) module. Once we import the `Pool` and define it (it's basically a pool of "*workers*" with the size of cores in your computer), then a map method will spread the calculations over the workers. As before, we write a wrapper function to ignore the extra nuisance parameters in `J_obs`, but in this case using a real function.

# %%
from multiprocessing import Pool

def cost_f2 (pp):
    return J_obs(pp,x,y,unc,model=dbl_logistic_model)**2 


pool = Pool()
print "Multicore:"
# %time costf = np.array(pool.map(cost_f2, LUT))

print "Singlecore"
# %time cost = np.array(map (cost_f, LUT))

print np.allclose (cost, costf)

# %% [markdown]
# On my laptop, this provides a speedup of around 3x.
#
# <div style="padding: 20px;
#     background-color: #f44336;
#     color: white;
#     font-size: 130%">
# Warning! If you use multiprocessing, you will use all of the computer resources. Be gentle with other users, and use <tt>nice -19 jupyter notebook</tt> when launching the notebook (see <a href="https://www.cyberciti.biz/faq/change-the-nice-value-of-a-process/">here</a> for more information).
# </div>

# %% [markdown]
# ## Exercise

# %% [markdown]
# Although we have not used the fact in the example above, the real benefit of a LUT is that you can *pre-calculate* the results at each of the grid points. This means that if you had a computationally expensive model, you could calculate $\hat{y}(x)$ for all grid points (note that this would be quite a large dataset).
#
# Implement a LUT optimisation approach (with a smaller grid than that used above). To do this:
#
# 1. calculate the grid points, similarly to above (but perhaps a bit smaller)
# 2. calculate and store $\hat{y}(x)$ for each grid point.
# 3. Calculate the cost $J$ between a particular observation (i.e. the values of LAI for a given pixel) and the LUT values (normalise dby uncertainty)
# 4. Find the minimum over the LUT and the associated parameter values
#
# You should then plot your results as above.
#
# Since we have to calculate $\hat{y}(x)$ at all grid points, generating the LUT might take a few minutes.
#
# What then is the advantage of this approach?

# %% [markdown]
# ## Using a minimisation routine

# %% [markdown]
# Although there are sometimes great practical advantages to using a LUT, there can be distinct downsides too (e.g. quantisation).
#
# Another approach is that we use some 'algorithm' that seeks the N-dimensional minimum by 'moving' around the parameter space.
#
# One such approach, and generally a useful algorithm is [L-BFGS-B](http://docs.scipy.org/doc/scipy-0.14.0/reference/generated/scipy.optimize.fmin_l_bfgs_b.html).

# %%
from scipy import optimize

p = result

# initial estimate is in p
print 'initial parameters:',p[0],p[1],p[2],p[3],p[4],p[5]

# set some bounds for the parameters
bound = np.array([(0.01,10.),(0.01,10.),(0.01,1.),\
                  (50.,300.),(0.01,1.),(50.,300.)])



def sse(p,x,y,unc):
    '''Sum of squared error'''
    # penalise p[3] > p[5]
    err = np.max([0.,(p[3] - p[5])])*1e4
    return J_obs(p,x,y,unc,model=dbl_logistic_model)+err

# we pass the function:
#
# sse               : the name of the function we wrote to give 
#                     sum of squares of Z_i
# p                 : an initial estimate of the parameters
# args=(x,y,unc)    : the other information (other than p) that
#                     mismatch_function needs
# approx_grad       : if we dont have a function for the gradien
#                     we have to get the solver to approximate it
#                     which takes time ... see if you can work out
#                     d_sse / dp and use that to speed this up!

psolve = optimize.fmin_l_bfgs_b(sse,p,approx_grad=True,iprint=1,\
                                args=(x,y,unc),bounds=bound)

print psolve[1]
pp = psolve[0]
plt.plot(x,y,'*')
plt.errorbar(x,y,unc*1.96)
y_hat = dbl_logistic_model(pp,x_full)
plt.plot(x_full,y_hat)

print 'solved parameters: ',pp[0],pp[1],pp[2],pp[3],pp[4],pp[5]

print '\nJ(min) = ',J_obs(p,x,y,unc,model=dbl_logistic_model)

# if we define the phenology as the parameter p[3]
# and the 'length' of the growing season:
print '\nphenology',pp[3],pp[5]-pp[3]

# %% [markdown]
# which gives a much more plausible result and a *much* lower SSE and took around 100 iterations (so a few hundred calculations of the cost function).

# %% [markdown]
# ## Exercise

# %% [markdown]
# Consider what the advantages and disadvantages of this sort of approach might be (e.g. compared to the LUT) (e.g. depending on whther there are *many* models to fit or only a few).
#
# The uncertainty in the parameters can be obtained from the Hessian of the cost function. See if you can work out how that might be calculated.
